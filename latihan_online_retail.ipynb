# %% [markdown]
# <a href="https://colab.research.google.com/github/yotart/android-kotlin-fundamentals-starter-apps/blob/master/latihan_online_retail.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data

# %%
import pandas as pd

# %%
df = pd.read_excel('https://raw.github.com/yotart/online_retail/main/Online%20Retail.xlsx')

# %%
df.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...

# %%
pip install sqlalchemy psycopg2-binary

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
DATABASE_URL = (
"postgresql://postgres.dbamclthcwanalmrwrhw:Supabase_MyProject@aws-1-ap-northeast-1.pooler.supabase.com:6543/postgres"
)

engine = create_engine(DATABASE_URL)

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.to_sql("online_retail", engine, if_exists="replace", index=False)
# Out:
# 909

# %% [markdown]
# #Statsitik Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  541909.000000                         541909  541909.000000
# mean        9.552250  2011-07-04 13:34:57.156386048       4.611114
# min    -80995.000000            2010-12-01 08:26:00  -11062.060000
# 25%         1.000000            2011-03-28 11:34:00       1.250000
# 50%         3.000000            2011-07-19 17:17:00       2.080000
# 75%        10.000000            2011-10-19 11:27:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       218.081158                            NaN      96.759853
#
#           CustomerID
# count  406829.000000
# mean    15287.690570
# min     12346.000000
# 25%     13953.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1713.600303

# %% [markdown]
# #Data Cleaning

# %% [markdown]
# ##Data Duplikat

# %%
#Data Duplikat
df.duplicated ().sum()
# Out:
# np.int64(5268)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##Missing Value

# %%
#Data Missing Value
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135037
# Country             0
# dtype: int64

# %% [markdown]
# ##Ubah Tipe Data

# %%
df['InvoiceDate']=pd.to_datetime(df['InvoiceDate']).dt.date
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01       2.55     17850.0  United Kingdom
# 1  2010-12-01       3.39     17850.0  United Kingdom
# 2  2010-12-01       2.75     17850.0  United Kingdom
# 3  2010-12-01       3.39     17850.0  United Kingdom
# 4  2010-12-01       3.39     17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 536641 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    536641 non-null  object
#  1   StockCode    536641 non-null  object
#  2   Description  535187 non-null  object
#  3   Quantity     536641 non-null  int64
#  4   InvoiceDate  536641 non-null  object
#  5   UnitPrice    536641 non-null  float64
#  6   CustomerID   401604 non-null  float64
#  7   Country      536641 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 36.8+ MB

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01       2.55     17850.0  United Kingdom
# 1  2010-12-01       3.39     17850.0  United Kingdom
# 2  2010-12-01       2.75     17850.0  United Kingdom
# 3  2010-12-01       3.39     17850.0  United Kingdom
# 4  2010-12-01       3.39     17850.0  United Kingdom

# %% [markdown]
# #Tambah Kolom

# %%
df['TotalPrice'] = df['Quantity']*df['UnitPrice']
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 0  2010-12-01       2.55     17850.0  United Kingdom       15.30
# 1  2010-12-01       3.39     17850.0  United Kingdom       20.34
# 2  2010-12-01       2.75     17850.0  United Kingdom       22.00
# 3  2010-12-01       3.39     17850.0  United Kingdom       20.34
# 4  2010-12-01       3.39     17850.0  United Kingdom       20.34

# %% [markdown]
# #Insight

# %% [markdown]
# ## 1.Tampilan Top Selling produk berdasarkan total transaksi

# %%
df.groupby(['StockCode','Description'])['Quantity'].sum().sort_values(ascending=False)
# Out:
# StockCode  Description
# 84077      WORLD WAR 2 GLIDERS ASSTD DESIGNS    53751
# 85099B     JUMBO BAG RED RETROSPOT              47260
# 22197      POPCORN HOLDER                       36322
# 84879      ASSORTED COLOUR BIRD ORNAMENT        36282
# 21212      PACK OF 72 RETROSPOT CAKE CASES      36016
#                                                 ...
# 20713      wrongly marked. 23343 in box         -3100
# 79323W     Unsaleable, destroyed.               -4830
# 72140F     throw away                           -5368
# 23003      Printing smudges/thrown away         -9058
# 23005      printing smudges/thrown away        -19200
# Name: Quantity, Length: 4792, dtype: int64

# %% [markdown]
# ## 2.Customer loyal berdasarkan jumlah pengeluaran

# %%
df.groupby(['CustomerID','Country'])['TotalPrice'].sum().sort_values(ascending=False)
# Out:
# CustomerID  Country
# 14646.0     Netherlands       279489.02
# 18102.0     United Kingdom    256438.49
# 17450.0     United Kingdom    187322.17
# 14911.0     EIRE              132458.73
# 12415.0     Australia         123725.45
#                                 ...
# 12503.0     Spain              -1126.00
# 17603.0     United Kingdom     -1165.30
# 14213.0     United Kingdom     -1192.20
# 15369.0     United Kingdom     -1592.49
# 17448.0     United Kingdom     -4287.63
# Name: TotalPrice, Length: 4380, dtype: float64

# %% [markdown]
# ## 3.Mengetahui revenue loss berdasarkan kegagalan transaksi

# %%
df['Transaction_Status']=~df['InvoiceNo'].astype(str).str.startswith('C')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 0  2010-12-01       2.55     17850.0  United Kingdom       15.30
# 1  2010-12-01       3.39     17850.0  United Kingdom       20.34
# 2  2010-12-01       2.75     17850.0  United Kingdom       22.00
# 3  2010-12-01       3.39     17850.0  United Kingdom       20.34
# 4  2010-12-01       3.39     17850.0  United Kingdom       20.34
#
#    Transaction_Status
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True

# %%
df['Transaction_Status'].value_counts()
# Out:
# Transaction_Status
# True     527390
# False      9251
# Name: count, dtype: int64

# %% [markdown]
# ### Jumlah Nilai hilang karena Pembatalan Transaksi

# %%
sukses = df[df['TotalPrice'] > 0]
gagal = df[df['TotalPrice'] < 0]

nilai_sukses = sukses['TotalPrice'].sum()
nilai_gagal = gagal['TotalPrice'].sum()
absolute_gagal = abs(nilai_gagal)
net = nilai_sukses - absolute_gagal
persentase = (absolute_gagal / nilai_sukses) * 100
persentase
# Out:
# np.float64(8.608290844478601)

# %% [markdown]
# ## 4.Mengetahui Produk yang sering dibatalkan transaksi

# %%
df.groupby('Description')['Transaction_Status'].sum().sort_values(ascending=False)
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    2315
# JUMBO BAG RED RETROSPOT               2112
# REGENCY CAKESTAND 3 TIER              2009
# PARTY BUNTING                         1700
# LUNCH BAG RED RETROSPOT               1581
#                                       ...
# CRUK Commission                          0
# CREAM SWEETHEART MAGAZINE RACK           0
# CREAM SWEETHEART SHELF + HOOKS           0
# CREAM SWEETHEART TRAYS                   0
# ANTIQUE LILY FAIRY LIGHTS                0
# Name: Transaction_Status, Length: 4223, dtype: int64

# %% [markdown]
# ## 5.Melihat Penjualan perhari

# %%
df.groupby('InvoiceDate')['Quantity'].sum().sort_values(ascending=False)
# Out:
# InvoiceDate
# 2011-10-05    46097
# 2011-11-14    45842
# 2011-12-05    44038
# 2011-09-20    43659
# 2011-10-20    40738
#               ...
# 2011-07-03     3080
# 2011-03-13     2725
# 2011-02-13     2682
# 2011-02-06     2036
# 2011-06-14   -13774
# Name: Quantity, Length: 305, dtype: int64

# %% [markdown]
# ## 6.Top Purchasing Countries berdasarkan total transaksi

# %%
df['Country'].value_counts()
# Out:
# Country
# United Kingdom          490300
# Germany                   9480
# France                    8541
# EIRE                      8184
# Spain                     2528
# Netherlands               2371
# Belgium                   2069
# Switzerland               1994
# Portugal                  1510
# Australia                 1258
# Norway                    1086
# Italy                      803
# Channel Islands            757
# Finland                    695
# Cyprus                     611
# Sweden                     461
# Unspecified                442
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     294
# USA                        291
# Hong Kong                  284
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %% [markdown]
# ## 7.Country wise revenue berdasarkan total price

# %%
df.groupby('Country')['TotalPrice'].sum().sort_values(ascending=False)
# Out:
# Country
# United Kingdom          8167128.184
# Netherlands              284661.540
# EIRE                     262993.380
# Germany                  221509.470
# France                   197317.110
# Australia                137009.770
# Switzerland               56363.050
# Spain                     54756.030
# Belgium                   40910.960
# Sweden                    36585.410
# Japan                     35340.620
# Norway                    35163.460
# Portugal                  29302.970
# Finland                   22326.740
# Channel Islands           20076.390
# Denmark                   18768.140
# Italy                     16890.510
# Cyprus                    12858.760
# Austria                   10154.320
# Hong Kong                  9908.240
# Singapore                  9120.390
# Israel                     7901.970
# Poland                     7213.140
# Unspecified                4740.940
# Greece                     4710.520
# Iceland                    4310.000
# ...

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

username = "postgres.dbamclthcwanalmrwrhw"
password = quote_plus("Supabase_MyProject")
host = "aws-1-ap-northeast-1.pooler.supabase.com"
port = "6543"
database = "postgres"

DATABASE_URL = (
    f"postgresql://{username}:{password}@{host}:{port}/{database}"
)

engine = create_engine(DATABASE_URL)

# %%
df.to_sql('online_retail1', con=engine, schema='public', if_exists='replace', index=False)
# Out:
# 641
